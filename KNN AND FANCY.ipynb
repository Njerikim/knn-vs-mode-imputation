# %%
import pandas as pd
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer

# %%
df = pd.read_csv("synthetic_dataset.csv")
df
# Out:
#    customer_id first_name last_name   age      city signup_date  \
# 0     CUST0001    Michael    Otieno  29.0   Nairobi  2024-01-21
# 1     CUST0002        NaN    Chebet  56.0    Nakuru  2023-12-20
# 2     CUST0003    Njoroge    Wambui  19.0   Nairobi  2023-02-09
# 3     CUST0004      David       NaN  20.0   Eldoret  2025-03-21
# 4     CUST0005      Linda  Odhiambo  54.0    Nakuru  2024-06-03
# ..         ...        ...       ...   ...       ...         ...
# 95    CUST0096      Susan    Wambui  19.0    Nakuru  2025-10-28
# 96    CUST0097       Mary   Kariuki  52.0       NaN  2024-12-15
# 97    CUST0098      James   Wanjiru   NaN     Nyeri         NaN
# 98    CUST0099    Achieng    Mwangi  58.0  Machakos  2023-07-17
# 99    CUST0100     Robert       NaN   NaN    Nakuru  2023-02-16
#
#    product_category  purchase_amount_kes  quantity payment_method  \
# 0           Fashion              6836.99       7.0            NaN
# 1       Electronics              4539.52       8.0           Card
# 2               NaN              5064.24       1.0  Bank Transfer
# 3              Toys             10153.27       6.0  Bank Transfer
# 4         Groceries             11335.14       1.0            NaN
# ..              ...                  ...       ...            ...
# 95    Home & Living                  NaN       NaN           Card
# 96          Fashion              6390.00       9.0           Cash
# 97        Groceries             14004.38       3.0            NaN
# 98            Books             13017.75       3.0  Bank Transfer
# 99             Toys                  NaN       2.0           Cash
#
#     satisfaction_score is_repeat_customer
# 0                  1.0               True
# 1                  3.0               True
# 2                  1.0                NaN
# 3                  NaN              False
# 4                  3.0              False
# ..                 ...                ...
# 95                 5.0               True
# 96                 1.0              False
# 97                 1.0              False
# 98                 5.0                NaN
# 99                 5.0              False
#
# [100 rows x 12 columns]

# %%
df.isna()
# Out:
#     customer_id  first_name  last_name    age   city  signup_date  \
# 0         False       False      False  False  False        False
# 1         False        True      False  False  False        False
# 2         False       False      False  False  False        False
# 3         False       False       True  False  False        False
# 4         False       False      False  False  False        False
# ..          ...         ...        ...    ...    ...          ...
# 95        False       False      False  False  False        False
# 96        False       False      False  False   True        False
# 97        False       False      False   True  False         True
# 98        False       False      False  False  False        False
# 99        False       False       True   True  False        False
#
#     product_category  purchase_amount_kes  quantity  payment_method  \
# 0              False                False     False            True
# 1              False                False     False           False
# 2               True                False     False           False
# 3              False                False     False           False
# 4              False                False     False            True
# ..               ...                  ...       ...             ...
# 95             False                 True      True           False
# 96             False                False     False           False
# 97             False                False     False            True
# 98             False                False     False           False
# 99             False                 True     False           False
#
#     satisfaction_score  is_repeat_customer
# 0                False               False
# 1                False               False
# 2                False                True
# 3                 True               False
# 4                False               False
# ..                 ...                 ...
# 95               False               False
# 96               False               False
# 97               False               False
# 98               False                True
# 99               False               False
#
# [100 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# customer_id             0
# first_name             18
# last_name              18
# age                     8
# city                   16
# signup_date            10
# product_category       17
# purchase_amount_kes    11
# quantity               18
# payment_method         28
# satisfaction_score     16
# is_repeat_customer     14
# dtype: int64

# %%
df_imputer_knn_sklearn = df.copy(deep = True)
df_imputer_knn_sklearn
# Out:
#    customer_id first_name last_name   age      city signup_date  \
# 0     CUST0001    Michael    Otieno  29.0   Nairobi  2024-01-21
# 1     CUST0002        NaN    Chebet  56.0    Nakuru  2023-12-20
# 2     CUST0003    Njoroge    Wambui  19.0   Nairobi  2023-02-09
# 3     CUST0004      David       NaN  20.0   Eldoret  2025-03-21
# 4     CUST0005      Linda  Odhiambo  54.0    Nakuru  2024-06-03
# ..         ...        ...       ...   ...       ...         ...
# 95    CUST0096      Susan    Wambui  19.0    Nakuru  2025-10-28
# 96    CUST0097       Mary   Kariuki  52.0       NaN  2024-12-15
# 97    CUST0098      James   Wanjiru   NaN     Nyeri         NaN
# 98    CUST0099    Achieng    Mwangi  58.0  Machakos  2023-07-17
# 99    CUST0100     Robert       NaN   NaN    Nakuru  2023-02-16
#
#    product_category  purchase_amount_kes  quantity payment_method  \
# 0           Fashion              6836.99       7.0            NaN
# 1       Electronics              4539.52       8.0           Card
# 2               NaN              5064.24       1.0  Bank Transfer
# 3              Toys             10153.27       6.0  Bank Transfer
# 4         Groceries             11335.14       1.0            NaN
# ..              ...                  ...       ...            ...
# 95    Home & Living                  NaN       NaN           Card
# 96          Fashion              6390.00       9.0           Cash
# 97        Groceries             14004.38       3.0            NaN
# 98            Books             13017.75       3.0  Bank Transfer
# 99             Toys                  NaN       2.0           Cash
#
#     satisfaction_score is_repeat_customer
# 0                  1.0               True
# 1                  3.0               True
# 2                  1.0                NaN
# 3                  NaN              False
# 4                  3.0              False
# ..                 ...                ...
# 95                 5.0               True
# 96                 1.0              False
# 97                 1.0              False
# 98                 5.0                NaN
# 99                 5.0              False
#
# [100 rows x 12 columns]

# %%
df_imputer_knn_sklearn.isna().sum()
# Out:
# customer_id             0
# first_name             18
# last_name              18
# age                     8
# city                   16
# signup_date            10
# product_category       17
# purchase_amount_kes    11
# quantity               18
# payment_method         28
# satisfaction_score     16
# is_repeat_customer     14
# dtype: int64

# %%
num_cols = ['age', 'purchase_amount_kes', 'quantity', 'satisfaction_score']
df_num = df[num_cols].copy()
df_num
# Out:
#      age  purchase_amount_kes  quantity  satisfaction_score
# 0   29.0              6836.99       7.0                 1.0
# 1   56.0              4539.52       8.0                 3.0
# 2   19.0              5064.24       1.0                 1.0
# 3   20.0             10153.27       6.0                 NaN
# 4   54.0             11335.14       1.0                 3.0
# ..   ...                  ...       ...                 ...
# 95  19.0                  NaN       NaN                 5.0
# 96  52.0              6390.00       9.0                 1.0
# 97   NaN             14004.38       3.0                 1.0
# 98  58.0             13017.75       3.0                 5.0
# 99   NaN                  NaN       2.0                 5.0
#
# [100 rows x 4 columns]

# %%
knn_imp = KNNImputer(n_neighbors = 5)
df_knn = pd.DataFrame(knn_imp.fit_transform(df_num), columns = num_cols)
df_knn
# Out:
#      age  purchase_amount_kes  quantity  satisfaction_score
# 0   29.0             6836.990       7.0                 1.0
# 1   56.0             4539.520       8.0                 3.0
# 2   19.0             5064.240       1.0                 1.0
# 3   20.0            10153.270       6.0                 3.2
# 4   54.0            11335.140       1.0                 3.0
# ..   ...                  ...       ...                 ...
# 95  19.0             5960.450       1.8                 5.0
# 96  52.0             6390.000       9.0                 1.0
# 97  39.2            14004.380       3.0                 1.0
# 98  58.0            13017.750       3.0                 5.0
# 99  26.6             8511.024       2.0                 5.0
#
# [100 rows x 4 columns]

# %%
from sklearn.impute import SimpleImputer
cat_cols = df.select_dtypes(include ='object').columns
cat_imp = SimpleImputer(strategy = 'most_frequent')
df_cat = pd.DataFrame(cat_imp.fit_transform(df[cat_cols]), columns = cat_cols)
df_cat
# Out:
#    customer_id first_name last_name      city signup_date product_category  \
# 0     CUST0001    Michael    Otieno   Nairobi  2024-01-21          Fashion
# 1     CUST0002      Linda    Chebet    Nakuru  2023-12-20      Electronics
# 2     CUST0003    Njoroge    Wambui   Nairobi  2023-02-09      Electronics
# 3     CUST0004      David    Chebet   Eldoret  2025-03-21             Toys
# 4     CUST0005      Linda  Odhiambo    Nakuru  2024-06-03        Groceries
# ..         ...        ...       ...       ...         ...              ...
# 95    CUST0096      Susan    Wambui    Nakuru  2025-10-28    Home & Living
# 96    CUST0097       Mary   Kariuki   Nairobi  2024-12-15          Fashion
# 97    CUST0098      James   Wanjiru     Nyeri  2023-02-12        Groceries
# 98    CUST0099    Achieng    Mwangi  Machakos  2023-07-17            Books
# 99    CUST0100     Robert    Chebet    Nakuru  2023-02-16             Toys
#
#    payment_method is_repeat_customer
# 0            Card               True
# 1            Card               True
# 2   Bank Transfer              False
# 3   Bank Transfer              False
# 4            Card              False
# ..            ...                ...
# 95           Card               True
# 96           Cash              False
# 97           Card              False
# 98  Bank Transfer              False
# 99           Cash              False
#
# [100 rows x 8 columns]

# %%
df_final = pd.concat([df_knn,df_cat], axis = 1)
df_final
# Out:
#      age  purchase_amount_kes  quantity  satisfaction_score customer_id  \
# 0   29.0             6836.990       7.0                 1.0    CUST0001
# 1   56.0             4539.520       8.0                 3.0    CUST0002
# 2   19.0             5064.240       1.0                 1.0    CUST0003
# 3   20.0            10153.270       6.0                 3.2    CUST0004
# 4   54.0            11335.140       1.0                 3.0    CUST0005
# ..   ...                  ...       ...                 ...         ...
# 95  19.0             5960.450       1.8                 5.0    CUST0096
# 96  52.0             6390.000       9.0                 1.0    CUST0097
# 97  39.2            14004.380       3.0                 1.0    CUST0098
# 98  58.0            13017.750       3.0                 5.0    CUST0099
# 99  26.6             8511.024       2.0                 5.0    CUST0100
#
#    first_name last_name      city signup_date product_category payment_method  \
# 0     Michael    Otieno   Nairobi  2024-01-21          Fashion           Card
# 1       Linda    Chebet    Nakuru  2023-12-20      Electronics           Card
# 2     Njoroge    Wambui   Nairobi  2023-02-09      Electronics  Bank Transfer
# 3       David    Chebet   Eldoret  2025-03-21             Toys  Bank Transfer
# 4       Linda  Odhiambo    Nakuru  2024-06-03        Groceries           Card
# ..        ...       ...       ...         ...              ...            ...
# 95      Susan    Wambui    Nakuru  2025-10-28    Home & Living           Card
# 96       Mary   Kariuki   Nairobi  2024-12-15          Fashion           Cash
# 97      James   Wanjiru     Nyeri  2023-02-12        Groceries           Card
# 98    Achieng    Mwangi  Machakos  2023-07-17            Books  Bank Transfer
# 99     Robert    Chebet    Nakuru  2023-02-16             Toys           Cash
#
#    is_repeat_customer
# 0                True
# 1                True
# 2               False
# 3               False
# 4               False
# ..                ...
# 95               True
# 96              False
# 97              False
# 98              False
# 99              False
#
# [100 rows x 12 columns]

# %%
df_final = df_final[df.columns]
df_final
# Out:
#    customer_id first_name last_name   age      city signup_date  \
# 0     CUST0001    Michael    Otieno  29.0   Nairobi  2024-01-21
# 1     CUST0002      Linda    Chebet  56.0    Nakuru  2023-12-20
# 2     CUST0003    Njoroge    Wambui  19.0   Nairobi  2023-02-09
# 3     CUST0004      David    Chebet  20.0   Eldoret  2025-03-21
# 4     CUST0005      Linda  Odhiambo  54.0    Nakuru  2024-06-03
# ..         ...        ...       ...   ...       ...         ...
# 95    CUST0096      Susan    Wambui  19.0    Nakuru  2025-10-28
# 96    CUST0097       Mary   Kariuki  52.0   Nairobi  2024-12-15
# 97    CUST0098      James   Wanjiru  39.2     Nyeri  2023-02-12
# 98    CUST0099    Achieng    Mwangi  58.0  Machakos  2023-07-17
# 99    CUST0100     Robert    Chebet  26.6    Nakuru  2023-02-16
#
#    product_category  purchase_amount_kes  quantity payment_method  \
# 0           Fashion             6836.990       7.0           Card
# 1       Electronics             4539.520       8.0           Card
# 2       Electronics             5064.240       1.0  Bank Transfer
# 3              Toys            10153.270       6.0  Bank Transfer
# 4         Groceries            11335.140       1.0           Card
# ..              ...                  ...       ...            ...
# 95    Home & Living             5960.450       1.8           Card
# 96          Fashion             6390.000       9.0           Cash
# 97        Groceries            14004.380       3.0           Card
# 98            Books            13017.750       3.0  Bank Transfer
# 99             Toys             8511.024       2.0           Cash
#
#     satisfaction_score is_repeat_customer
# 0                  1.0               True
# 1                  3.0               True
# 2                  1.0              False
# 3                  3.2              False
# 4                  3.0              False
# ..                 ...                ...
# 95                 5.0               True
# 96                 1.0              False
# 97                 1.0              False
# 98                 5.0              False
# 99                 5.0              False
#
# [100 rows x 12 columns]
